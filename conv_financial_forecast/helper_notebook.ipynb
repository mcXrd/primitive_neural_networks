# %%
import pandas as pd

# %%
df = pd.read_hdf("binance_data_sep_16.hdf")

# %%
df = df.dropna()
df
# Out:
#                                     ENJBNB  MKRBNB  VTHOBUSD  LTCTUSD  \
# 2020-09-16 13:00:59.999000+00:00  0.005730  17.013  0.000806    48.16
# 2020-09-16 13:01:59.999000+00:00  0.005730  17.013  0.000806    47.99
# 2020-09-16 13:02:59.999000+00:00  0.005730  17.013  0.000806    47.99
# 2020-09-16 13:03:59.999000+00:00  0.005730  17.013  0.000806    47.99
# 2020-09-16 13:04:59.999000+00:00  0.005730  17.079  0.000806    47.99
# ...                                    ...     ...       ...      ...
# 2020-09-16 21:09:59.999000+00:00  0.005615  17.117  0.000804    48.08
# 2020-09-16 21:10:59.999000+00:00  0.005615  17.117  0.000804    48.08
# 2020-09-16 21:11:59.999000+00:00  0.005615  17.117  0.000804    48.08
# 2020-09-16 21:12:59.999000+00:00  0.005615  17.117  0.000806    48.08
# 2020-09-16 21:13:59.999000+00:00  0.005615  17.117  0.000806    48.08
#
#                                   ANKRUSDT  WINGBUSD   LTCETH    QSPBTC  \
# ...

# %%
df.iloc[-6:].values
# Out:
# array([[5.6150e-03, 1.7051e+01, 8.0400e-04, ..., 8.3580e+00, 6.1500e-06,
#         4.9100e-03],
#        [5.6150e-03, 1.7117e+01, 8.0400e-04, ..., 8.3580e+00, 6.1300e-06,
#         4.9100e-03],
#        [5.6150e-03, 1.7117e+01, 8.0400e-04, ..., 8.3580e+00, 6.1200e-06,
#         4.9100e-03],
#        [5.6150e-03, 1.7117e+01, 8.0400e-04, ..., 8.3580e+00, 6.1400e-06,
#         4.9100e-03],
#        [5.6150e-03, 1.7117e+01, 8.0600e-04, ..., 8.3580e+00, 6.1200e-06,
#         4.9100e-03],
#        [5.6150e-03, 1.7117e+01, 8.0600e-04, ..., 8.3580e+00, 6.1200e-06,
#         4.9100e-03]])

# %%
len(df)
# Out:
# 494
